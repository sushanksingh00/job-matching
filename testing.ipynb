# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer
from PyPDF2 import PdfReader
import re

# %%
reader = PdfReader("resume.pdf")
number_of_pages = len(reader.pages)
resume_text = ""
for page in reader.pages:
    resume_text += page.extract_text() or ""
# Out:
# Resume pages: 1
# Raw resume_text chars: 3232
# Raw resume preview:
#  Sushank Singh
# Ayodhya, Uttar Pradesh
# ♂phone+91 8318740001/envel⌢pesushankk00@gmail.com/linkedinLinkedIn/githubGitHub
# Profile
# Computer Science student at VIT-AP (Batch 2024) with a strong academic record (CGPA: 9.06) and solid fundamentals.
# Proficient in Data Structures and Algorithms, with a experience in software development and real-world applications through the
# projects.
# Passionate about contributing technical and analytical skills to impactful projects.
# Education
# VIT-AP University — Amarava

# %%
import nltk
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

ps = PorterStemmer()

def remove_stop_words(text):
    text = text.lower()
    text = text.replace('\n',' ')
    text = re.sub(r'[^a-zA-Z ]', '', text)
    words = text.split()
    words = [ps.stem(w) for w in words if w not in stop_words]
    return ' '.join(words)

# %%
job_desc = """
Python Developer Intern

Responsibilities:
- Develop backend applications using Python and Flask
- Work with REST APIs and database systems
- Perform debugging and testing of code
- Collaborate on backend architecture

Requirements:
- Strong knowledge of Python
- Familiarity with Flask or FastAPI
- Basic understanding of databases (MySQL/SQLite)
- Problem-solving skills
"""

# %%
def compute_similarity(job, resume):
    tfidf = TfidfVectorizer()
    vectors = tfidf.fit_transform([resume, job])
    score = cosine_similarity(vectors[0], vectors[1])[0][0]
    return score

# %%
job = remove_stop_words(job_desc)
resume = remove_stop_words(resume_text)
print("Resume:", resume[:500])
print("Job:", job)
# Out:
# Cleaned resume chars: 2454
# Cleaned job chars: 261
# Resume (cleaned preview): sushank singh ayodhya uttar pradesh phone+91 8318740001 envel pesushankk00 gmail.com linkedinlinkedin githubgithub profil comput scienc student vit ap batch 2024 strong academ record cgpa 9.06 solid fundamentals. profici data structur algorithm experi softwar develop real world applic projects. passion contribut technic analyt skill impact projects. educ vit ap univers amaravati ap2024 2028 b.tech. comput scienc engin cgpa 9.06 kendriya vidyalaya ayodhya class x xii score 91 86 technolog languag
# Job (cleaned): python develop intern respons develop backend applic use python flask work rest api databas system perform debug test code collabor backend architectur requir strong knowledg python familiar flask fastapi basic understand databas mysql sqlite problem solv skill

# %%
sim = compute_similarity(job, resume)
print(sim)
# Out:
# Similarity (word TF-IDF):  0.088693
# Similarity (hybrid TF-IDF): 0.175265

# %%
# Out:
# raw unigram (english stopwords) -> 0.131455
# raw bigram (english stopwords) -> 0.065439
# normalized no-stem bigram      -> 0.064988
# normalized stem bigram         -> 0.088693
# normalized no-stem + char      -> 0.164626
# char_wb only (3-5)             -> 0.264264
#
# Token overlap count: 15
# Some overlaps: ['apis', 'applications', 'backend', 'database', 'databases', 'developer', 'fastapi', 'flask', 'mysql', 'python', 'rest', 'skills', 'strong', 'systems', 'using']
